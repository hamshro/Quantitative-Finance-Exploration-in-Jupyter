# 2020-12-30  54.029999  371.570007  135.580002  54.049999  372.339996
# 2020-12-31  54.270000  371.230011  134.080002  54.450001  371.779999
#
# Price          Volume
# Ticker           AAPL        KO        SPY
# Date
# 2010-01-04  493729600  13870400  118944600
# 2010-01-05  601904800  23172400  111579900
# 2010-01-06  552160000  19264600  116074400
# 2010-01-07  477131200  13234600  131091100
# 2010-01-08  447610800  28712400  126402800
# ...               ...       ...        ...
# 2020-12-24   54930100   3265500   26457900
# 2020-12-28  124486200   9020500   39000400
# 2020-12-29  121047300   8320600   53680500
# 2020-12-30   96452100   8142700   49455300
# 2020-12-31   99116600   8495000   78520700
#
# [2769 rows x 18 columns]

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            names=['Price', 'Ticker'])

# %%
#convert mult index to one tuple
stocks.columns=stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'KO'),  ('Adj Close', 'SPY'),
#            ('Close', 'AAPL'),       ('Close', 'KO'),      ('Close', 'SPY'),
#             ('High', 'AAPL'),        ('High', 'KO'),       ('High', 'SPY'),
#              ('Low', 'AAPL'),         ('Low', 'KO'),        ('Low', 'SPY'),
#             ('Open', 'AAPL'),        ('Open', 'KO'),       ('Open', 'SPY'),
#           ('Volume', 'AAPL'),      ('Volume', 'KO'),     ('Volume', 'SPY')],
#       dtype='object')

# %%
stocks
# Out:
#             (Adj Close, AAPL)  (Adj Close, KO)  (Adj Close, SPY)  \
# Date
# 2010-01-04           6.470741        18.351234         86.860054
# 2010-01-05           6.481928        18.129244         87.090034
# 2010-01-06           6.378825        18.122805         87.151291
# 2010-01-07           6.367030        18.077765         87.519203
# 2010-01-08           6.409362        17.743176         87.810425
# ...                       ...              ...               ...
# 2020-12-24         129.514450        48.392033        351.874786
# 2020-12-28         134.146622        49.044022        354.897614
# 2020-12-29         132.360489        49.016857        354.220551
# 2020-12-30         131.231888        49.297573        354.725952
# 2020-12-31         130.221085        49.659790        356.528259
#
#             (Close, AAPL)  (Close, KO)  (Close, SPY)  (High, AAPL)  \
# Date
# 2010-01-04       7.643214    28.520000    113.330002      7.660714
# 2010-01-05       7.656429    28.174999    113.629997      7.699643
# 2010-01-06       7.534643    28.165001    113.709999      7.686786
# 2010-01-07       7.520714    28.094999    114.190002      7.571429
# 2010-01-08       7.570714    27.575001    114.570000      7.571429
# ...                   ...          ...           ...           ...
# 2020-12-24     131.970001    53.439999    369.000000    133.460007
#
#                               High                                Low  \
#                    SPY        AAPL         KO         SPY        AAPL
# Date
# 2010-01-04  113.330002    7.660714  28.610001  113.389999    7.585000
# 2010-01-05  113.629997    7.699643  28.495001  113.680000    7.616071
# 2010-01-06  113.709999    7.686786  28.219999  113.989998    7.526786
# 2010-01-07  114.190002    7.571429  28.184999  114.330002    7.466071
# 2010-01-08  114.570000    7.571429  27.820000  114.620003    7.466429
# ...                ...         ...        ...         ...         ...
# 2020-12-24  369.000000  133.460007  53.549999  369.029999  131.100006
# 2020-12-28  372.170013  137.339996  54.439999  372.589996  133.509995
# 2020-12-29  371.459991  138.789993  54.490002  374.000000  134.339996
# 2020-12-30  371.989990  135.990005  54.630001  373.100006  133.399994
# 2020-12-31  373.880005  134.740005  54.930000  374.660004  131.720001
#
#                                          Open                         \
#                    KO         SPY        AAPL         KO         SPY
# Date
# 2010-01-04  28.450001  111.510002    7.622500  28.580000  112.370003
# 2010-01-05  28.070000  112.849998    7.664286  28.424999  113.260002
# 2010-01-06  27.990000  113.430000    7.656429  28.174999  113.519997
# 2010-01-07  27.875000  113.180000    7.562500  28.165001  113.500000
# 2010-01-08  27.375000  113.660004    7.510714  27.730000  113.889999
# ...               ...         ...         ...        ...         ...
# 2020-12-24  53.020000  367.450012  131.320007  53.020000  368.079987
# 2020-12-28  53.730000  371.070007  133.990005  53.849998  371.739990
# 2020-12-29  54.020000  370.829987  138.050003  54.450001  373.809998
# 2020-12-30  54.029999  371.570007  135.580002  54.049999  372.339996
# 2020-12-31  54.270000  371.230011  134.080002  54.450001  371.779999
#
#                Volume
#                  AAPL        KO        SPY
# Date
# 2010-01-04  493729600  13870400  118944600
# 2010-01-05  601904800  23172400  111579900
# 2010-01-06  552160000  19264600  116074400
# 2010-01-07  477131200  13234600  131091100
# 2010-01-08  447610800  28712400  126402800
# ...               ...       ...        ...
# 2020-12-24   54930100   3265500   26457900
# 2020-12-28  124486200   9020500   39000400
# 2020-12-29  121047300   8320600   53680500
# 2020-12-30   96452100   8142700   49455300
# 2020-12-31   99116600   8495000   78520700
#
# [2769 rows x 18 columns]

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %%
stocks.describe()
# Out:
#          Adj Close                                  Close               \
#               AAPL           KO          SPY         AAPL           KO
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# mean     31.522342    31.953174   181.488475    33.777537    41.320121
# std      24.583424     8.118784    69.487675    24.572747     6.808527
# min       5.806766    16.243889    79.026405     6.858929    25.014999
# 25%      15.181946    26.394423   114.525375    17.484285    37.660000
# 50%      24.517967    31.516817   175.435959    26.987499    41.759998
# 75%      40.879475    37.329926   241.183365    43.007500    45.549999
# max     134.146622    52.648426   356.528259   136.690002    60.130001
#
#                            High                                    Low  \
#                SPY         AAPL           KO          SPY         AAPL
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# mean    207.676797    34.114230    41.583236   208.716963    33.413543
# std      67.240791    24.895185     6.864731    67.589965    24.220789
# min     102.199997     7.000000    25.150000   103.419998     6.794643
# 25%     141.559998    17.695356    37.919998   142.100006    17.333929
# 50%     205.210007    27.225000    41.980000   206.190002    26.705000
# 75%     265.339996    43.367500    45.799999   267.320007    42.605000
# max     373.880005   138.789993    60.130001   378.459991   134.339996
#
#                                         Open                            \
#                 KO          SPY         AAPL           KO          SPY
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# mean     41.042551   206.475522    33.764375    41.314411   207.648136
# std       6.755616    66.883703    24.561595     6.807492    67.258092
# min      24.735001   101.129997     6.870357    25.110001   103.110001
# 25%      37.419998   140.929993    17.518213    37.700001   141.660004
# 50%      41.529999   204.110001    26.975000    41.750000   204.960007
# 75%      45.310001   263.390015    43.012501    45.549999   265.779999
# max      59.619999   371.570007   138.050003    59.810001   373.809998
#
#              Volume
#                AAPL            KO           SPY
# count  2.769000e+03  2.769000e+03  2.769000e+03
# mean   2.866162e+08  1.502133e+07  1.244573e+08
# std    2.289459e+08  6.716946e+06  7.477756e+07
# min    4.544800e+07  2.996300e+06  2.027000e+07
# 25%    1.211120e+08  1.071810e+07  7.292670e+07
# 50%    2.029972e+08  1.350830e+07  1.045961e+08
# 75%    3.890376e+08  1.751480e+07  1.539926e+08
# max    1.880998e+09  9.896750e+07  7.178287e+08

# %%
close=stocks.loc[:,"Close"].copy()

# %%
close
# Out:
#                   AAPL         KO         SPY
# Date
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# 2010-01-08    7.570714  27.575001  114.570000
# ...                ...        ...         ...
# 2020-12-24  131.970001  53.439999  369.000000
# 2020-12-28  136.690002  54.160000  372.170013
# 2020-12-29  134.869995  54.130001  371.459991
# 2020-12-30  133.720001  54.439999  371.989990
# 2020-12-31  132.690002  54.840000  373.880005
#
# [2769 rows x 3 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")

# %%
close.plot(figsize=(15,7),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
close.iloc[0,0]
# Out:
# 7.643214225769043

# %%
close.AAPL
# Out:
# Date
# 2010-01-04      7.643214
# 2010-01-05      7.656429
# 2010-01-06      7.534643
# 2010-01-07      7.520714
# 2010-01-08      7.570714
#                  ...
# 2020-12-24    131.970001
# 2020-12-28    136.690002
# 2020-12-29    134.869995
# 2020-12-30    133.720001
# 2020-12-31    132.690002
# Name: AAPL, Length: 2769, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0])
# Out:
# Date
# 2010-01-04     1.000000
# 2010-01-05     1.001729
# 2010-01-06     0.985795
# 2010-01-07     0.983973
# 2010-01-08     0.990514
#                 ...
# 2020-12-24    17.266296
# 2020-12-28    17.883838
# 2020-12-29    17.645717
# 2020-12-30    17.495258
# 2020-12-31    17.360498
# Name: AAPL, Length: 2769, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2010-01-04     100.000000
# 2010-01-05     100.172893
# 2010-01-06      98.579511
# 2010-01-07      98.397266
# 2010-01-08      99.051443
#                  ...
# 2020-12-24    1726.629626
# 2020-12-28    1788.383766
# 2020-12-29    1764.571699
# 2020-12-30    1749.525753
# 2020-12-31    1736.049763
# Name: AAPL, Length: 2769, dtype: float64

# %%
close.div(close.iloc[0]).mul(100)
# Out:
#                    AAPL          KO         SPY
# Date
# 2010-01-04   100.000000  100.000000  100.000000
# 2010-01-05   100.172893   98.790318  100.264710
# 2010-01-06    98.579511   98.755261  100.335302
# 2010-01-07    98.397266   98.509814  100.758846
# 2010-01-08    99.051443   96.686537  101.094148
# ...                 ...         ...         ...
# 2020-12-24  1726.629626  187.377271  325.597806
# 2020-12-28  1788.383766  189.901820  328.394959
# 2020-12-29  1764.571699  189.796635  327.768451
# 2020-12-30  1749.525753  190.883583  328.236111
# 2020-12-31  1736.049763  192.286112  329.903820
#
# [2769 rows x 3 columns]

# %%
normclose=close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,7),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
aapl=close.AAPL.copy().to_frame()

# %%
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002
#
# [2769 rows x 1 columns]

# %%
aapl.shift(periods=1)
# Out:
#                   AAPL
# Date
# 2010-01-04         NaN
# 2010-01-05    7.643214
# 2010-01-06    7.656429
# 2010-01-07    7.534643
# 2010-01-08    7.520714
# ...                ...
# 2020-12-24  130.960007
# 2020-12-28  131.970001
# 2020-12-29  136.690002
# 2020-12-30  134.869995
# 2020-12-31  133.720001
#
# [2769 rows x 1 columns]

# %%
aapl["lag1"]=aapl.shift(periods=1)

# %%
aapl
# Out:
#                   AAPL        lag1
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    7.643214
# 2010-01-06    7.534643    7.656429
# 2010-01-07    7.520714    7.534643
# 2010-01-08    7.570714    7.520714
# ...                ...         ...
# 2020-12-24  131.970001  130.960007
# 2020-12-28  136.690002  131.970001
# 2020-12-29  134.869995  136.690002
# 2020-12-30  133.720001  134.869995
# 2020-12-31  132.690002  133.720001
#
# [2769 rows x 2 columns]

# %%
aapl["Diff"]=aapl.AAPL.subtract(aapl.lag1)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff
# Date
# 2010-01-04    7.643214         NaN       NaN
# 2020-12-29  134.869995  136.690002 -1.820007  0.986685  0.986685 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994  0.991473  0.991473 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999  0.992297  0.992297 -1.029999
#
#             % Change 2
# Date
# 2010-01-04         NaN
# 2010-01-05    0.172893
# 2010-01-06   -1.590632
# 2010-01-07   -0.184871
# 2010-01-08    0.664833
# ...                ...
# 2020-12-24    0.771224
# 2020-12-28    3.576571
# 2020-12-29   -1.331485
# 2020-12-30   -0.852668
# 2020-12-31   -0.770265
#
# [2769 rows x 7 columns]

# %%
del aapl["& Change"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '& Change'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 del aapl["& Change"]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4441, in NDFrame.__delitem__(self, key)
#    4436             deleted = True
#    4437 if not deleted:
#    4438     # If the above loop ran and didn't delete anything because
#    4439     # there was no match, this call should raise the appropriate
#    4440     # exception:
# -> 4441     loc = self.axes[-1].get_loc(key)
#    4442     self._mgr = self._mgr.idelete(loc)
#    4444 # delete from the caches
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: '& Change'

# %%
del aapl["% Change"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '% Change'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 del aapl["% Change"]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4441, in NDFrame.__delitem__(self, key)
#    4436             deleted = True
#    4437 if not deleted:
#    4438     # If the above loop ran and didn't delete anything because
#    4439     # there was no match, this call should raise the appropriate
#    4440     # exception:
# -> 4441     loc = self.axes[-1].get_loc(key)
#    4442     self._mgr = self._mgr.idelete(loc)
#    4444 # delete from the caches
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: '% Change'

# %%
del aapl["Diff2"]

# %%
aapl
# Out:
#                   AAPL  % Change 2
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    0.172893
# 2010-01-06    7.534643   -1.590632
# 2010-01-07    7.520714   -0.184871
# 2010-01-08    7.570714    0.664833
# ...                ...         ...
# 2020-12-24  131.970001    0.771224
# 2020-12-28  136.690002    3.576571
# 2020-12-29  134.869995   -1.331485
# 2020-12-30  133.720001   -0.852668
# 2020-12-31  132.690002   -0.770265
#
# [2769 rows x 2 columns]

# %%
aapl.rename(columns = {'% Change 2': 'Change'}, inplace=True)

# %%
aapl
# Out:
#                   AAPL    Change
# Date
# 2010-01-04    7.643214       NaN
# 2010-01-05    7.656429  0.172893
# 2010-01-06    7.534643 -1.590632
# 2010-01-07    7.520714 -0.184871
# 2010-01-08    7.570714  0.664833
# ...                ...       ...
# 2020-12-24  131.970001  0.771224
# 2020-12-28  136.690002  3.576571
# 2020-12-29  134.869995 -1.331485
# 2020-12-30  133.720001 -0.852668
# 2020-12-31  132.690002 -0.770265
#
# [2769 rows x 2 columns]

# %%
aapl.AAPL.resample("M").last()
# Out:
# Date
# 2010-01-31      6.859286
# 2010-02-28      7.307857
# 2010-03-31      8.392857
# 2010-04-30      9.324643
# 2010-05-31      9.174286
#                  ...
# 2020-08-31    129.039993
# 2020-09-30    115.809998
# 2020-10-31    108.860001
# 2020-11-30    119.050003
# 2020-12-31    132.690002
# Freq: M, Name: AAPL, Length: 132, dtype: float64

# %%
aapl.AAPL.resample("BM").last().pct_change(periods=1).mul(100)
# Out:
# Date
# 2010-01-29          NaN
# 2010-02-26     6.539620
# 2010-03-31    14.847028
# 2010-04-30    11.102138
# 2010-05-31    -1.612472
#                 ...
# 2020-08-31    21.437974
# 2020-09-30   -10.252632
# 2020-10-30    -6.001206
# 2020-11-30     9.360649
# 2020-12-31    11.457370
# Freq: BM, Name: AAPL, Length: 132, dtype: float64

# %%
aapl
# Out:
#                   AAPL    Change
# Date
# 2010-01-04    7.643214       NaN
# 2010-01-05    7.656429  0.172893
# 2010-01-06    7.534643 -1.590632
# 2010-01-07    7.520714 -0.184871
# 2010-01-08    7.570714  0.664833
# ...                ...       ...
# 2020-12-24  131.970001  0.771224
# 2020-12-28  136.690002  3.576571
# 2020-12-29  134.869995 -1.331485
# 2020-12-30  133.720001 -0.852668
# 2020-12-31  132.690002 -0.770265
#
# [2769 rows x 2 columns]

# %%
del aapl["Change"]

# %%
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002
#
# [2769 rows x 1 columns]

# %%
ret = aapl.pct_change().dropna()

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2768 entries, 2010-01-05 to 2020-12-31
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    2768 non-null   float64
# dtypes: float64(1)
# memory usage: 43.2 KB

# %%
ret.plot(kind="hist",figsize=(12,8), bins=100)
plt.show()

# %%
daily_mean_return=ret.mean()
daily_mean_return
# Out:
# AAPL    0.001191
# dtype: float64

# %%
var_daily=ret.var()
var_daily
# Out:
# AAPL    0.000318
# dtype: float64

# %%
std_daily=np.sqrt(var_daily)

# %%
std_daily
# Out:
# AAPL    0.017843
# dtype: float64

# %%
ret.std()
# Out:
# AAPL    0.017843
# dtype: float64

# %%
annual_mean_ret=daily_mean_return*252
annual_mean_ret
# Out:
# AAPL    0.300134
# dtype: float64

# %%
annual_var_return=var_daily*252
annual_var_return
# Out:
# AAPL    0.080226
# dtype: float64

# %%
annual_std_returns=np.sqrt(annual_var_return)
annual_std_returns
# Out:
# AAPL    0.283242
# dtype: float64

# %%
ret.std()*np.sqrt(252)
# Out:
# AAPL    0.283242
# dtype: float64

# %%
ticker=["SPY","AAPL","KO","IBM","DIS","MSFT"]

# %%
stocks=yf.download(ticker, start="2010-01-01", end="2021-01-01")
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
stocks
# Out:
# Price        Adj Close                                                 \
# Ticker            AAPL         DIS         IBM         KO        MSFT
# Date
# 2010-01-04    6.470741   27.843176   76.767426  18.351234   23.431597
# 2010-01-05    6.481928   27.773720   75.840080  18.129244   23.439152
# 2010-01-06    6.378825   27.626125   75.347420  18.122805   23.295317
# 2010-01-07    6.367030   27.634809   75.086601  18.077765   23.053047
# 2010-01-08    6.409362   27.678217   75.840080  17.743176   23.212044
# ...                ...         ...         ...        ...         ...
# 2020-12-24  129.514450  173.165634  102.086227  48.392033  216.523849
ontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
ret=close.pct_change().dropna()
ret.head()
# Out:
# Ticker          AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821 -0.016311 -0.010470  0.020308 -0.012720  0.001397

# %%
ret.describe().T
# Out:
#          count      mean       std       min       25%       50%       75%  \
# Ticker
# AAPL    2768.0  0.001191  0.017843 -0.128647 -0.007123  0.000903  0.010379
# DIS     2768.0  0.000749  0.015717 -0.129846 -0.006210  0.000629  0.007901
# IBM     2768.0  0.000082  0.014132 -0.128507 -0.006321  0.000287  0.006743
# KO      2768.0  0.000298  0.011088 -0.096725 -0.004698  0.000438  0.005706
# MSFT    2768.0  0.000841  0.016012 -0.147390 -0.006939  0.000654  0.008636
# SPY     2768.0  0.000491  0.010909 -0.109424 -0.003532  0.000637  0.005421
#
#              max
# Ticker
# AAPL    0.119808
# DIS     0.144123
# IBM     0.113010
# KO      0.064796
# MSFT    0.142169
# SPY     0.090603

# %%
summary=ret.describe().T.loc[:,["mean", "std"]]
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.001191  0.017843
# DIS     0.000749  0.015717
# IBM     0.000082  0.014132
# KO      0.000298  0.011088
# MSFT    0.000841  0.016012
# SPY     0.000491  0.010909

# %%
summary["mean"]=summary["mean"]*252
summary["std"]=summary["std"]*np.sqrt(252)

# %%
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.300134  0.283242
# DIS     0.188696  0.249504
# IBM     0.020648  0.224345
# KO      0.075091  0.176009
# MSFT    0.211915  0.254185
# SPY     0.123754  0.173170

# %%
summary.plot.scatter(x="std",y="mean",figsize=(12,8),s=50,fontsize=15)
for i in summary.index:
    plt.annotate(i,xy=(summary.loc[i,"std"]+0.002,summary.loc[i,"mean"]+0.002),size=15)
plt.xlabel("Annual risk(std)", fontsize=15)
plt.ylabel("Annual return", fontsize=15)
plt.title("Risk/Return", fontsize=50)
# Out:
# Text(0.5, 1.0, 'Risk/Return')

# %%
fruits = ["aaple","banana","mango"]
for i in fruits:
    print(i)
# Out:
# aaple
# banana
# mango

# %% [markdown]
# ## Covariance and Correlation

# %%
ret
# Out:
# Ticker          AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821 -0.016311 -0.010470  0.020308 -0.012720  0.001397
# ...              ...       ...       ...       ...       ...       ...
# 2020-12-24  0.007712  0.001037  0.006376  0.006782  0.007827  0.003890
# 2020-12-28  0.035766  0.029529  0.001043  0.013473  0.009921  0.008591
# 2020-12-29 -0.013315 -0.008722 -0.008172 -0.000554 -0.003601 -0.001908
# 2020-12-30 -0.008527  0.021827  0.004362  0.005727 -0.011019  0.001427
# 2020-12-31 -0.007703  0.000055  0.012385  0.007348  0.003338  0.005081
#
# [2768 rows x 6 columns]

# %%
ret.cov()
# Out:
# Ticker      AAPL       DIS       IBM        KO      MSFT       SPY
# Ticker
# AAPL    0.000318  0.000115  0.000110  0.000067  0.000158  0.000128
# DIS     0.000115  0.000247  0.000111  0.000085  0.000121  0.000121
# IBM     0.000110  0.000111  0.000200  0.000079  0.000121  0.000108
# KO      0.000067  0.000085  0.000079  0.000123  0.000076  0.000077
# MSFT    0.000158  0.000121  0.000121  0.000076  0.000256  0.000130
# SPY     0.000128  0.000121  0.000108  0.000077  0.000130  0.000119

# %%
ret.corr()
# Out:
# Ticker      AAPL       DIS       IBM        KO      MSFT       SPY
# Ticker
# AAPL    1.000000  0.408513  0.436100  0.339213  0.554051  0.659557
# DIS     0.408513  1.000000  0.497775  0.486514  0.480457  0.706726
# IBM     0.436100  0.497775  1.000000  0.502436  0.533130  0.703342
# KO      0.339213  0.486514  0.502436  1.000000  0.429749  0.639324
# MSFT    0.554051  0.480457  0.533130  0.429749  1.000000  0.744601
# SPY     0.659557  0.706726  0.703342  0.639324  0.744601  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(),cmap="Reds",annot=True,annot_kws={"size":15},vmax=0.6)
plt.show()

# %%
ticker=["TEO","LQDH","AFL","KALL","JULZ","SRI","FGEN","CSX","WBIL","BRFH","IPAR","CRAK","SAIA","PCG","MTG","GS","LILMW","MCRB","KIM","CPK"]

# %%
stocks=yf.download(ticker, start="2010-01-01", end="2021-01-01")
# Out:
# [*********************100%%**********************]  20 of 20 completed

# %%
close=stocks.loc[:,"Close"].copy()

# %%
normclose=close.div(close.iloc[0].mul(100))

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %% [markdown]
# # 20 Random Stock Analysis
# https://www.rayberger.org/random-stock-picker/

# %%
ret=close.pct_change().dropna()
ret.head()
# Out:
# Ticker           AFL      BRFH       CPK      CRAK       CSX      FGEN  \
# Date
# 2020-11-24  0.037795  0.086957  0.031136  0.030509  0.009342  0.028365
# 2020-11-25 -0.011273 -0.040000 -0.003066  0.002352 -0.007318 -0.031696
# 2020-11-27 -0.007235  0.000000 -0.012861 -0.006676 -0.010299  0.003748
# 2020-11-30 -0.029814  0.083333 -0.018032 -0.032994 -0.013583  0.028379
# 2020-12-01  0.017528 -0.076923  0.004999  0.020893  0.006330 -0.001452
#
# Ticker            GS      IPAR      JULZ      KALL       KIM     LILMW  \
# Date
# 2020-11-24  0.037888  0.058802  0.013424  0.005226 -0.011531  0.086957
# 2020-11-25 -0.004042 -0.013223 -0.001480 -0.005488 -0.010369  0.022222
# 2020-11-27 -0.004819 -0.010541  0.001976  0.013651 -0.013098  0.169565
# 2020-11-30 -0.020476 -0.019321 -0.004613 -0.025502 -0.041805 -0.018587
# 2020-12-01  0.006505  0.026514  0.010683  0.011173  0.024931  0.003788
#
# Ticker          LQDH      MCRB       MTG       PCG      SAIA       SRI  \
# Date
# 2020-11-24  0.000850 -0.099765  0.029703  0.009449  0.032908  0.032246
# 2020-11-25  0.002229 -0.042047 -0.016026 -0.014041 -0.014814 -0.028007
# 2020-11-27  0.000360 -0.012930 -0.014658  0.007120  0.006154 -0.000739
# 2020-11-30  0.003028 -0.048259 -0.011570 -0.002357  0.007155 -0.007024
# 2020-12-01  0.003304 -0.045636  0.009197 -0.000787  0.012318  0.013403
#
# Ticker           TEO      WBIL
# Date
# 2020-11-24  0.072776  0.015068
# 2020-11-25  0.030151  0.001462
# 2020-11-27  0.003659  0.005769
# 2020-11-30  0.024301 -0.001379
# 2020-12-01 -0.003559 -0.001745

# %%
summary=ret.describe().T.loc[:,["mean", "std"]]

# %%
summary["mean"]=summary["mean"]*252
summary["std"]=summary["std"]*np.sqrt(252)

# %%
summary.plot.scatter(x="std",y="mean",figsize=(12,8),s=50,fontsize=15)
for i in summary.index:
    plt.annotate(i,xy=(summary.loc[i,"std"]+0.002,summary.loc[i,"mean"]+0.002),size=15)
plt.xlabel("Annual risk(std)", fontsize=15)
plt.ylabel("Annual return", fontsize=15)
plt.title("Risk/Return", fontsize=50)
# Out:
# Text(0.5, 1.0, 'Risk/Return')

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.0)
sns.heatmap(ret.corr(),cmap="Reds",annot=True,annot_kws={"size":10},vmax=0.6)
plt.show()

# %% [markdown]
# # Simple Returns and Log Returns

# %%
df = pd.DataFrame(index=[2016,2017,2018],data=[100,50,95],columns=["Price"])

# %%
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
simplereturns=df.pct_change().dropna()

# %%
simplereturns
# Out:
#       Price
# 2017   -0.5
# 2018    0.9

# %%
simplereturns.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
100*1.2*1.2
# Out:
# 144.0

# %%
#Mean returns are misleading af

# %%
logreturns=np.log(df/df.shift(1)).dropna()
logreturns
# Out:
#          Price
# 2017 -0.693147
# 2018  0.641854

# %%
logreturns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
100*np.exp(logreturns.mean()*2)
# Out:
# Price    95.0
# dtype: float64

# %% [markdown]
# # Moving Averages

# %%
SPY = yf.download("SPY")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
SPY
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-29   43.968750   43.968750   43.750000   43.937500   24.763723
# 1993-02-01   43.968750   44.250000   43.968750   44.250000   24.939869
# 1993-02-02   44.218750   44.375000   44.125000   44.343750   24.992699
# 1993-02-03   44.406250   44.843750   44.375000   44.812500   25.256897
# 1993-02-04   44.968750   45.093750   44.468750   45.000000   25.362572
# ...                ...         ...         ...         ...         ...
# 2024-04-29  510.089996  510.750000  507.250000  510.059998  510.059998
# 2024-04-30  508.559998  509.559998  501.980011  501.980011  501.980011
# 2024-05-01  501.380005  508.190002  499.869995  500.350006  500.350006
# 2024-05-02  504.149994  505.890015  499.549988  505.029999  505.029999
# 2024-05-03  511.160004  512.549988  508.559998  511.290009  511.290009
#
#               Volume
# Date
# 1993-01-29   1003200
# 1993-02-01    480500
# 1993-02-02    201300
# 1993-02-03    529400
# 1993-02-04    531500
# ...              ...
# 2024-04-29  46415400
# 2024-04-30  77483600
# 2024-05-01  80242800
# 2024-05-02  62550200
# 2024-05-03  72756709
#
# [7872 rows x 6 columns]

# %%
spy=SPY.Close.to_frame()

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2024-04-29  510.059998
# 2024-04-30  501.980011
# 2024-05-01  500.350006
# 2024-05-02  505.029999
# 2024-05-03  511.290009
#
# [7872 rows x 1 columns]

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy_roll=spy.rolling(window=10)

# %%
spy_roll=spy_roll.mean()

# %%
spy_roll.head(15)
# Out:
#                 Close
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04        NaN
# 1993-02-05        NaN
# 1993-02-08        NaN
# 1993-02-09        NaN
# 1993-02-10        NaN
# 1993-02-11  44.659375
# 1993-02-12  44.725000
# 1993-02-16  44.646875
# 1993-02-17  44.556250
# 1993-02-18  44.415625
# 1993-02-19  44.271875

# %%
spy.rolling(window=10).median()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2024-04-29  503.509995
# 2024-04-30  502.735001
# 2024-05-01  502.735001
# 2024-05-02  504.259995
# 2024-05-03  505.220001
#
# [7872 rows x 1 columns]

# %%
spy.rolling(window=10).max()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2024-04-29  510.059998
# 2024-04-30  510.059998
# 2024-05-01  510.059998
# 2024-05-02  510.059998
# 2024-05-03  511.290009
#
# [7872 rows x 1 columns]

# %%
spy.rolling(window=10,min_periods=5).max().head(15)
# Out:
#                Close
# Date
# 1993-01-29       NaN
# 1993-02-01       NaN
# 1993-02-02       NaN
# 1993-02-03       NaN
# 1993-02-04  45.00000
# 1993-02-05  45.00000
# 1993-02-08  45.00000
# 1993-02-09  45.00000
# 1993-02-10  45.00000
# 1993-02-11  45.00000
# 1993-02-12  45.00000
# 1993-02-16  45.00000
# 1993-02-17  45.00000
# 1993-02-18  45.00000
# 1993-02-19  44.96875

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2024-04-29  510.059998
# 2024-04-30  501.980011
# 2024-05-01  500.350006
# 2024-05-02  505.029999
# 2024-05-03  511.290009
#
# [7872 rows x 1 columns]

# %%
spy["SMA50"]=spy.rolling(window=50,min_periods=50).mean()

# %%
spy.head(52)
# Out:
#                Close     SMA50
# Date
# 1993-01-29  43.93750       NaN
# 1993-02-01  44.25000       NaN
# 1993-02-02  44.34375       NaN
# 1993-02-03  44.81250       NaN
# 1993-02-04  45.00000       NaN
# 1993-02-05  44.96875       NaN
# 1993-02-08  44.96875       NaN
# 1993-02-09  44.65625       NaN
# 1993-02-10  44.71875       NaN
# 1993-02-11  44.93750       NaN
# 1993-02-12  44.59375       NaN
# 1993-02-16  43.46875       NaN
# 1993-02-17  43.43750       NaN
# 1993-02-18  43.40625       NaN
# 1993-02-19  43.56250       NaN
# 1993-02-22  43.71875       NaN
# 1993-02-23  43.68750       NaN
# 1993-02-24  44.25000       NaN
# 1993-02-25  44.34375       NaN
# 1993-02-26  44.40625       NaN
# 1993-03-01  44.28125       NaN
# 1993-03-02  44.93750       NaN
# 1993-03-03  45.12500       NaN
# 1993-03-04  44.87500       NaN
# 1993-03-05  44.75000       NaN
# 1993-03-08  45.75000       NaN
# 1993-03-09  45.59375       NaN
# 1993-03-10  45.68750       NaN
# 1993-03-11  45.56250       NaN
# 1993-03-12  45.09375       NaN
# 1993-03-15  45.31250       NaN
# 1993-03-16  45.31250       NaN
# 1993-03-17  45.03125       NaN
# 1993-03-18  45.31250       NaN
# 1993-03-19  45.03125       NaN
# 1993-03-22  44.78125       NaN
# 1993-03-23  44.87500       NaN
# 1993-03-24  44.87500       NaN
# 1993-03-25  45.15625       NaN
# 1993-03-26  44.90625       NaN
# 1993-03-29  45.09375       NaN
# 1993-03-30  45.21875       NaN
# 1993-03-31  45.18750       NaN
# 1993-04-01  45.03125       NaN
# 1993-04-02  44.09375       NaN
# 1993-04-05  44.31250       NaN
# 1993-04-06  44.18750       NaN
# 1993-04-07  44.34375       NaN
# 1993-04-08  44.28125       NaN
# 1993-04-12  44.90625  44.68750
# 1993-04-13  45.00000  44.70875
# 1993-04-14  44.93750  44.72250

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy["SMA200"]=spy.Close.rolling(window=200,min_periods=200).mean()
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy["EMA100"]=spy.Close.ewm(span=100,min_periods=100).mean()

# %%
spy
# Out:
#                  Close       SMA50      SMA200      EMA100
# Date
# 1993-01-29   43.937500         NaN         NaN         NaN
# 1993-02-01   44.250000         NaN         NaN         NaN
# 1993-02-02   44.343750         NaN         NaN         NaN
# 1993-02-03   44.812500         NaN         NaN         NaN
# 1993-02-04   45.000000         NaN         NaN         NaN
# ...                ...         ...         ...         ...
# 2024-04-29  510.059998  511.190198  468.098701  494.425037
# 2024-04-30  501.980011  511.239598  468.362201  494.574641
# 2024-05-01  500.350006  511.311398  468.609751  494.689004
# 2024-05-02  505.029999  511.467798  468.863951  494.893777
# 2024-05-03  511.290009  511.543599  469.144401  495.218454
#
# [7872 rows x 4 columns]

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy["Day"]=spy.index.day_name()

# %%
spy["Quarter"]=spy.index.quarter

# %%
SPY = yf.download("SPY")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
spy=spy.Close.to_frame()

# %%
all_days=pd.date_range(start="2010-12-31",end="2020-01-01",freq="D")

# %%
all_days
# Out:
# DatetimeIndex(['2010-12-31', '2011-01-01', '2011-01-02', '2011-01-03',
#                '2011-01-04', '2011-01-05', '2011-01-06', '2011-01-07',
#                '2011-01-08', '2011-01-09',
#                ...
#                '2019-12-23', '2019-12-24', '2019-12-25', '2019-12-26',
#                '2019-12-27', '2019-12-28', '2019-12-29', '2019-12-30',
#                '2019-12-31', '2020-01-01'],
#               dtype='datetime64[ns]', length=3289, freq='D')

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2024-04-29  510.059998
# 2024-04-30  501.980011
# 2024-05-01  500.350006
# 2024-05-02  505.029999
# 2024-05-03  511.290009
#
# [7872 rows x 1 columns]

# %%
spy.fillna(spy.ffill)
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2024-04-29  510.059998
# 2024-04-30  501.980011
# 2024-05-01  500.350006
# 2024-05-02  505.029999
# 2024-05-03  511.290009
#
# [7872 rows x 1 columns]

# %%
SPY = yf.download("SPY",interval="1wk")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
SPY
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-25   43.968750   43.968750   43.750000   43.937500   24.763737
# 1993-02-01   43.968750   45.093750   43.968750   44.968750   25.344954
# 1993-02-08   44.968750   45.125000   44.531250   44.593750   25.133625
# 1993-02-15   44.468750   44.468750   42.812500   43.562500   24.552378
# 1993-02-22   43.687500   44.437500   43.468750   44.406250   25.027918
# ...                ...         ...         ...         ...         ...
# 2024-04-01  523.830017  524.380005  512.760010  518.429993  518.429993
# 2024-04-08  519.150024  520.750000  509.079987  510.850006  510.850006
# 2024-04-15  515.130005  515.299988  493.859985  495.160004  495.160004
# 2024-04-22  497.829987  509.880005  495.429993  508.260010  508.260010
# 2024-04-29  510.089996  512.549988  499.549988  511.290009  511.290009
#
#                Volume
# Date
# 1993-01-25    1003200
# 1993-02-01    2234800
# 1993-02-08    1159800
# 1993-02-15     998700
# 1993-02-22    1024300
# ...               ...
# 2024-04-01  367203800
# 2024-04-08  361747100
# 2024-04-15  418172900
# 2024-04-22  321951200
# 2024-04-29  339448709
#
# [1632 rows x 6 columns]

# %% [markdown]
# # Cummulative Returns, Drawdowns, etc...

# %%
apple=yf.download("AAPL")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
apple=apple.Close.to_frame()

# %%
apple["d_returns"]=np.log(apple.div(apple.shift(1)))

# %%
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-12    0.128348        NaN
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# ...                ...        ...
# 2024-04-29  173.500000   0.024505
# 2024-04-30  170.330002  -0.018440
# 2024-05-01  169.300003  -0.006065
# 2024-05-02  173.029999   0.021793
# 2024-05-03  183.360001   0.057986
#
# [10939 rows x 2 columns]

# %%
apple.dropna(inplace=True)

# %%
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# 1980-12-19    0.126116   0.059239
# ...                ...        ...
# 2024-04-29  173.500000   0.024505
# 2024-04-30  170.330002  -0.018440
# 2024-05-01  169.300003  -0.006065
# 2024-05-02  173.029999   0.021793
# 2024-05-03  183.360001   0.057986
#
# [10938 rows x 2 columns]

# %%
apple.d_returns.sum()
# Out:
# 7.2644614463748445

# %%
np.exp(apple.d_returns.sum())
# Out:
# 1428.616034202046

# %%
apple["cummreturns"]=apple.d_returns.cumsum().apply(np.exp)

# %%
apple
# Out:
#                  Close  d_returns  cummreturns
# Date
# 1980-12-15    0.121652  -0.053581     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261
# 1980-12-17    0.115513   0.024450     0.899998
# 1980-12-18    0.118862   0.028580     0.926092
# 1980-12-19    0.126116   0.059239     0.982610
# ...                ...        ...          ...
# 2024-04-29  173.500000   0.024505  1351.793636
# 2024-04-30  170.330002  -0.018440  1327.095173
# 2024-05-01  169.300003  -0.006065  1319.070125
# 2024-05-02  173.029999   0.021793  1348.131707
# 2024-05-03  183.360001   0.057986  1428.616034
#
# [10938 rows x 3 columns]

# %%
apple.cummreturns.plot(figsize=(12,8),title="Apple buy and hold", fontsize=12)
plt.show()

# %%
apple.d_returns.mean()*252
# Out:
# 0.16736554072832885

# %%
apple.d_returns.std()*np.sqrt(252)
# Out:
# 0.4502850850257111

# %%
# how to calculate drawdowns

# %%
apple["cummax"]=apple.cummreturns.cummax()

# %%
apple
# Out:
#                  Close  d_returns  cummreturns       cummax
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829
# 1980-12-17    0.115513   0.024450     0.899998     0.947829
# 1980-12-18    0.118862   0.028580     0.926092     0.947829
# 1980-12-19    0.126116   0.059239     0.982610     0.982610
# ...                ...        ...          ...          ...
# 2024-04-29  173.500000   0.024505  1351.793636  1543.537972
# 2024-04-30  170.330002  -0.018440  1327.095173  1543.537972
# 2024-05-01  169.300003  -0.006065  1319.070125  1543.537972
# 2024-05-02  173.029999   0.021793  1348.131707  1543.537972
# 2024-05-03  183.360001   0.057986  1428.616034  1543.537972
#
# [10938 rows x 4 columns]

# %%
apple[["cummreturns","cummax"]].plot(figsize=(12,8),title="Apple buy and hold+cummax", fontsize=12)
plt.show()

# %%
apple["drawdown"]=apple["cummax"]-apple["cummreturns"]

# %%
apple
# Out:
#                  Close  d_returns  cummreturns       cummax    drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2024-04-29  173.500000   0.024505  1351.793636  1543.537972  191.744335
# 2024-04-30  170.330002  -0.018440  1327.095173  1543.537972  216.442799
# 2024-05-01  169.300003  -0.006065  1319.070125  1543.537972  224.467846
# 2024-05-02  173.029999   0.021793  1348.131707  1543.537972  195.406264
# 2024-05-03  183.360001   0.057986  1428.616034  1543.537972  114.921937
#
# [10938 rows x 5 columns]

# %%
apple.drawdown.max()
# Out:
# 444.02718404402026

# %%
apple.drawdown.idxmax()
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
apple.loc[(apple.index<='2023-01-05')]
# Out:
#                  Close  d_returns  cummreturns       cummax    drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2022-12-29  129.610001   0.027931  1009.832703  1418.097708  408.265004
# 2022-12-30  129.929993   0.002466  1012.325863  1418.097708  405.771845
# 2023-01-03  125.070000  -0.038122   974.460113  1418.097708  443.637594
# 2023-01-04  126.360001   0.010261   984.510920  1418.097708  433.586787
# 2023-01-05  125.019997  -0.010661   974.070524  1418.097708  444.027184
#
# [10605 rows x 5 columns]

# %%
apple["drawdown%"]=apple["cummax"]-apple["cummreturns"]/apple["cummax"]

# %%
apple
# Out:
#                  Close  d_returns  cummreturns       cummax     drawdown  \
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    -0.052171
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829     0.021227
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    -0.001707
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    -0.029236
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    -0.017390
# ...                ...        ...          ...          ...          ...
# 2024-04-29  173.500000   0.024505  1351.793636  1543.537972  1542.662195
# 2024-04-30  170.330002  -0.018440  1327.095173  1543.537972  1542.678197
# 2024-05-01  169.300003  -0.006065  1319.070125  1543.537972  1542.683396
# 2024-05-02  173.029999   0.021793  1348.131707  1543.537972  1542.664568
# 2024-05-03  183.360001   0.057986  1428.616034  1543.537972  1542.612425
#
#               drawdown%
# Date
# 1980-12-15    -0.052171
# 1980-12-16     0.021227
# 1980-12-17    -0.001707
# 1980-12-18    -0.029236
# 1980-12-19    -0.017390
# ...                 ...
# 2024-04-29  1542.662195
# 2024-04-30  1542.678197
# 2024-05-01  1542.683396
# 2024-05-02  1542.664568
# 2024-05-03  1542.612425
#
# [10938 rows x 6 columns]

# %%
apple["drawdown%"].max()
# Out:
# 1542.705100937274

# %%
apple["drawdown%"].idxmax()
# Out:
# Timestamp('2024-04-19 00:00:00')

# %%
apple.loc[(apple.index<='2024-04-19')]
# Out:
#                  Close  d_returns  cummreturns       cummax     drawdown  \
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    -0.052171
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829     0.021227
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    -0.001707
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    -0.029236
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    -0.017390
# ...                ...        ...          ...          ...          ...
# 2024-04-15  172.690002  -0.022106  1345.482688  1543.537972  1542.666284
# 2024-04-16  169.380005  -0.019353  1319.693445  1543.537972  1542.682992
# 2024-04-17  168.000000  -0.008181  1308.941388  1543.537972  1542.689958
# 2024-04-18  167.039993  -0.005731  1301.461671  1543.537972  1542.694804
# 2024-04-19  165.000000  -0.012288  1285.567435  1543.537972  1542.705101
#
#               drawdown%
# Date
# 1980-12-15    -0.052171
# 1980-12-16     0.021227
# 1980-12-17    -0.001707
# 1980-12-18    -0.029236
# 1980-12-19    -0.017390
# ...                 ...
# 2024-04-15  1542.666284
# 2024-04-16  1542.682992
# 2024-04-17  1542.689958
# 2024-04-18  1542.694804
# 2024-04-19  1542.705101
#
# [10928 rows x 6 columns]

# %% [markdown]
# # SMA SRATEGY

# %%
data=apple.Close.loc[(apple.index>='1991-01-01')]

# %%
data=data.to_frame()

# %%
data
# Out:
#                  Close
# Date
# 1991-01-02    0.388393
# 1991-01-03    0.383929
# 1991-01-04    0.386161
# 1991-01-07    0.386161
# 1991-01-08    0.386161
# ...                ...
# 2024-04-29  173.500000
# 2024-04-30  170.330002
# 2024-05-01  169.300003
# 2024-05-02  173.029999
# 2024-05-03  183.360001
#
# [8398 rows x 1 columns]

# %%
sma_s=50
sma_l=100

# %%
data["sma_s"]=data.Close.rolling(sma_s).mean()
data["sma_l"]=data.Close.rolling(sma_l).mean()

# %%
data
# Out:
#                  Close     sma_s     sma_l
# Date
# 1991-01-02    0.388393       NaN       NaN
# 1991-01-03    0.383929       NaN       NaN
# 1991-01-04    0.386161       NaN       NaN
# 1991-01-07    0.386161       NaN       NaN
# 1991-01-08    0.386161       NaN       NaN
# ...                ...       ...       ...
# 2024-04-29  173.500000  173.0788  181.5812
# 2024-04-30  170.330002  172.8392  181.3503
# 2024-05-01  169.300003  172.5940  181.1201
# 2024-05-02  173.029999  172.4082  180.9077
# 2024-05-03  183.360001  172.3880  180.7842
#
# [8398 rows x 3 columns]

# %%
data.plot(figsize=(12,8),title="AAPLE = SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12)
plt.show()

# %%
data.loc["2016"].plot(figsize=(12,8),title="AAPLE = SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12)
plt.show()

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 1991-05-23    0.402902    0.534420    0.513326
# 1991-05-24    0.409598    0.530960    0.513538
# 1991-05-28    0.410714    0.527344    0.513806
# 1991-05-29    0.419643    0.523638    0.514141
# 1991-05-30    0.425223    0.519732    0.514531
# ...                ...         ...         ...
# 2024-04-29  173.500000  173.078800  181.581200
# 2024-04-30  170.330002  172.839200  181.350300
# 2024-05-01  169.300003  172.594000  181.120100
# 2024-05-02  173.029999  172.408200  180.907700
# 2024-05-03  183.360001  172.388000  180.784200
#
# [8299 rows x 3 columns]

# %%
data["position"]=np.where(data["sma_s"]>data["sma_l"],1,-1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1
# 1991-05-24    0.409598    0.530960    0.513538         1
# 1991-05-28    0.410714    0.527344    0.513806         1
# 1991-05-29    0.419643    0.523638    0.514141         1
# 1991-05-30    0.425223    0.519732    0.514531         1
# ...                ...         ...         ...       ...
# 2024-04-29  173.500000  173.078800  181.581200        -1
# 2024-04-30  170.330002  172.839200  181.350300        -1
# 2024-05-01  169.300003  172.594000  181.120100        -1
# 2024-05-02  173.029999  172.408200  180.907700        -1
# 2024-05-03  183.360001  172.388000  180.784200        -1
#
# [8299 rows x 4 columns]

# %%
data.loc["2016",["sma_s","sma_l","position"]].plot(figsize=(12,8),title="AAPLE = SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12,secondary_y="position")
# Out:
# <Axes: title={'center': 'AAPLE = SMA50 | SMA100'}, xlabel='Date'>

# %%
data["returnsb&h"]=np.log(data.Close.div(data.Close.shift(1)))

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  strategy
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1         NaN       NaN
# 1991-05-24    0.409598    0.530960    0.513538         1    0.016483       1.0
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721       1.0
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507       1.0
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209       1.0
# ...                ...         ...         ...       ...         ...       ...
# 2024-04-29  173.500000  173.078800  181.581200        -1    0.024505       1.0
# 2024-04-30  170.330002  172.839200  181.350300        -1   -0.018440       1.0
# 2024-05-01  169.300003  172.594000  181.120100        -1   -0.006065       1.0
# 2024-05-02  173.029999  172.408200  180.907700        -1    0.021793       1.0
# 2024-05-03  183.360001  172.388000  180.784200        -1    0.057986       1.0
#
# [8299 rows x 6 columns]

# %%
data["strategy"]=data["returnsb&h"]*data.position.shift(1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  strategy
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1         NaN       NaN
# 1991-05-24    0.409598    0.530960    0.513538         1    0.016483  0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721  0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507  0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209  0.013209
# ...                ...         ...         ...       ...         ...       ...
# 2024-04-29  173.500000  173.078800  181.581200        -1    0.024505 -0.024505
# 2024-04-30  170.330002  172.839200  181.350300        -1   -0.018440  0.018440
# 2024-05-01  169.300003  172.594000  181.120100        -1   -0.006065  0.006065
# 2024-05-02  173.029999  172.408200  180.907700        -1    0.021793 -0.021793
# 2024-05-03  183.360001  172.388000  180.784200        -1    0.057986 -0.057986
#
# [8299 rows x 6 columns]

# %%
data.dropna(inplace=True)

# %%
data[["returnsb&h","strategy"]].sum()
# Out:
# returnsb&h    6.120513
# strategy      1.768471
# dtype: float64

# %%
data[["returnsb&h","strategy"]].sum().apply(np.exp)
# Out:
# returnsb&h    455.098256
# strategy        5.861884
# dtype: float64

# %%
data[["returnsb&h","strategy"]].std()*np.sqrt(252)
# Out:
# returnsb&h    0.433350
# strategy      0.433495
# dtype: float64

# %%
data.Close.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Strategty adjusted with long bias

# %%
data["position2"]=np.where(data["sma_s"]>data["sma_l"],1,0)

# %%
data["strategy2"]=data["returnsb&h"]*data.position2.shift(1)

# %%
data.dropna(inplace=True)

# %%
data[["returnsb&h","strategy2"]].sum()
# Out:
# returnsb&h    6.101310
# strategy2     3.925288
# dtype: float64

# %%
data[["returnsb&h","strategy2"]].sum().apply(np.exp)
# Out:
# returnsb&h    446.442051
# strategy2      50.667693
# dtype: float64

# %%
data[["returnsb&h","strategy2"]].std()*np.sqrt(252)
# Out:
# returnsb&h    0.433394
# strategy2     0.334832
# dtype: float64

# %% [markdown]
# # Function and Class

# %%
def test_strategy(stock,start,end,SMA):
    df=yf.download(stock,start=start,end=end)
    data=df.Close.to_frame()
    data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
    data["SMA_S"]=data.Close.rolling(int(SMA[0])).mean()
    data["SMA_L"]=data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)
    
    
    data["position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
    data["strategy"]=data['returns']*data.position.shift(1)
    data.dropna(inplace=True)
    ret=np.exp(data["strategy"].sum())
    std=data["strategy"].std()*np.sqrt(252)
    
    return ret,std

# %%
test_strategy("MSFT","2000-01-01","2020-01-01",(50,200))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# (0.39097954932295986, 0.2906766831415824)

# %%
class SMABacktester():
    def __init__(self,symbol,SMA_S,SMA_L,start,end):
        self.symbol=symbol
        self.SMA_S=SMA_S
        self.SMA_L=SMA_L
        self.start=start
        self.end=end
        self.result=None
        self.get_data()
    def get_data(self):
        df=yf.download(self.symbol,start=self.start,end=self.end)
        data=df.Close.to_frame()
        data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
        data["SMA_S"]=data.Close.rolling(self.SMA_S).mean()
        data["SMA_L"]=data.Close.rolling(self.SMA_L).mean()
        data.dropna(inplace=True)
        self.data2=data
        
        return data
    def test_results(self):
        data=self.data2.copy().dropna()
        data["position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
        data["strategy"]=data['returns']*data.position.shift(1)
        data.dropna(inplace=True)
        data["returnsbh"]=data["returns"].cumsum().apply(np.exp)
        data["returnsstrategy"]=data["strategy"].cumsum().apply(np.exp)
        perf=data["returnsstrategy"].iloc[-1]               
        outperf=perf-data["returnsbh"].iloc[-1]       
        self.results=data
                                 
        ret=np.exp(data["strategy"].sum())
        std=data["strategy"].std()*np.sqrt(252)
            
        return round(perf,6), round(outperf,6)
                                 
    def plot_results(self):
        if self.results is None:
            print("run the test please0")
        else:
            title="{} | SMA_S={} | SMA_L={}".format(self.symbol,self.SMA_S,self.SMA_L)
            self.results[["returnsbh","returnsstrategy"]].plot(title=title, figsize=(12,8))

# %%
tester = SMABacktester("SPY",50,100,"2000-01-01","2020-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (2.592726, 0.297824)

# %%
tester.plot_results()
